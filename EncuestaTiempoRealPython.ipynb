# %% [markdown]
# <a href="https://colab.research.google.com/github/secun/ProgrammingAssignment2/blob/master/EncuestaTiempoRealPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Resultados en tiempo real
# Hay multitud de ejemplos en los que puede ser interesante trabajar casi en tiempo real con los resultados del trabajo de los alumnos. La siguiente herramienta puede volverse muy util para **el trabajo en un laboratorio** ya que convierte en algo practicamente instantaneo el procesamiento estadistico de datos.
#
#  Puede servir para involucrar a los alumnos diciendoles que compartan los resultados de una practica en los distintos apartados de un formulario de google y vean una comparativa con los de sus compañeros y un resultado global de la clase. Normalmente es importante repetir varias veces un experimento para obtener una buena estadistica y de este modo vamos a poder aglutinar toda la información de varios grupos realizando la misma practica simultaneamente.
#
#  En este caso como base para nuestro analisis usaremos los resultados de un cuestionario sobre la motivación de los estudiantes para trabajar la asignatura:
# [ https://forms.gle/YfLmS3tNtto7cq3h8](https://forms.gle/YfLmS3tNtto7cq3h8)

# %% [markdown]
# # Importar los resultados de un "google form"
# En la configuración del formulario de google nos permite almacenar automaticamente los resultados en una hoja de calculo de google. Podemos manipular esta hoja de forma sencilla instalando "gspread" y proporcionando las credenciales con el codigo que obtenemos tras acceder link que aparece en la consola.

# %%
# !pip install --upgrade gspread
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied, skipping upgrade: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from gspread) (0.4.2)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from gspread) (1.25.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (53.0.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (4.7)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.12.0->gspread) (0.4.8)

# %% [markdown]
# #Creación del DataFrame
# Tomamos las filas y las almacenamos en un dataframe con pandas

# %%
worksheet = gc.open('Motivación FyQ (respuestas)').sheet1

import pandas as pd
test=worksheet.get_all_records()
test_df=pd.DataFrame.from_records(test)
#test_df.head()

# %% [markdown]
# #Importamos el resto de librerias con las que vamos a trabajar

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Estadisticas basicas en un vistazo
# Con el metodo ".describe" de los dataframe obtenemos media, desviación y cuartiles de todos los apartados-

# %%
test_df.describe()
# Out:
#        2. Porque me resulta placentero aprender cosas nuevas.  ...  26. No lo sé, no comprendo que hago en esta asignatura
# count                                           5.000000       ...                                           4.000000
# mean                                            3.000000       ...                                           5.750000
# std                                             1.732051       ...                                           1.892969
# min                                             2.000000       ...                                           3.000000
# 25%                                             2.000000       ...                                           5.250000
# 50%                                             2.000000       ...                                           6.500000
# 75%                                             3.000000       ...                                           7.000000
# max                                             6.000000       ...                                           7.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# No todas las respuestas han sido tomadas como numéricas

# %%
#test_df.shape
test_df.info()
#test_df.nunique()
#test_df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 31 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Marca temporal                                                                                                    5 non-null      object
#  1   Dirección de correo electrónico                                                                                   5 non-null      object
#  2   Código del Alumno                                                                                                 5 non-null      object
#  3   2. Porque me resulta placentero aprender cosas nuevas.                                                            5 non-null      int64
#  4   9. Por el placer que experimento descubriendo cosas nuevas que no he visto antes.                                 5 non-null      int64
#  5   16. Por lo placentero que me resulta ampliar mi conocimiento en temas atractivos para mi.                         5 non-null      int64
#  6   23. Porque me permetirá continuar aprendiendo sobre cosas que me interesan.                                       5 non-null      object
#  7   6. Por el placer que siento al superarme a mi mismo en mis estudios.                                              5 non-null      int64
#  8   13. Porque me resulta placentero sobrepasarme a mi mismo obteniendo logros personales.                            5 non-null      object
#  9   20. Por la satisfacción que siento en el proceso de superar actividades académicas complejas.                     5 non-null      int64
#  10  27. Porque me permite experimentar satisfacción personal la búsqueda por sobresalir en mis estudios.              5 non-null      int64
#  11  4. Porque me gusta estar en clase de la asignatura                                                                5 non-null      int64
#  12  11. Para mi la clase de Física y Química es divertida                                                             5 non-null      int64
#  13  18. Por el placer que experimento involucrandome en discusiones interesantes sobre la asignatura con el profesor  5 non-null      object
#  14  25. Por la buena sensación que experimento leyendo sobre las cosas interesantes de la asignatura.                 5 non-null      int64
#  15  3. Porque pienso que me preparará mejor para el futuro profesional que he elegido.                                5 non-null      int64
#  16  10. Para que llegado el momento pueda acceder al mercado laboral en el campo que me gusta.                        5 non-null      int64
#  17  17. Porque me ayudará a tomar mejores decisiones respecto a mi futuro profesional.                                5 non-null      int64
#  18  24. Porque esta formación mejorará mis competencias como trabajador                                               5 non-null      int64
#  19  7. Para demostrarme a mis mismo que soy capaz de superar la  asignatura.                                          5 non-null      int64
#  20  14. Por el hecho de que me  siento importante teniendo éxito en la asignatura.                                    5 non-null      int64
#  21  21. Para demostrarme a mi mismo que soy una persona inteligente                                                   5 non-null      int64
#  22  28. Porque quiero demostrarme a mi mismo que puedo tener éxito en la asignatura.                                  5 non-null      int64
#  23  1. Porque necesito estos conocimientos para tener un trabajo bien pagado en el futuro                             5 non-null      int64
#  24  8. Para tener un trabajo mas prestigioso en el futuro.                                                            5 non-null      int64
#  25  15. Porque quiero tener "una buena vida" en el futuro.                                                            5 non-null      int64
#  26  22. Para tener un buen salario u otros beneficios en el futuro                                                    5 non-null      int64
#  27  5. Honestamente , no lo sé; realmente siento que estoy perdiendo el tiempo en esta asignatura.                    5 non-null      int64
#  28  12. En principio tenia buenos motivos para elegir esta asignatura, ahora me pregunto si debería seguir.           5 non-null      int64
#  29  19. Francamente no entiendo que hago en esta asignatura, no me podría importar menos.                             5 non-null      int64
#  30  26. No lo sé, no comprendo que hago en esta asignatura                                                            5 non-null      object
# dtypes: int64(24), object(7)
# memory usage: 1.3+ KB

# %%
for i in range(3, len(test_df.columns)):
    test_df.iloc[:,i] = pd.to_numeric(test_df.iloc[:,i], errors='ignore', downcast='float')
    test_df.iloc[:,i] = test_df.iloc[:,i].astype(float)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 31 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Marca temporal                                                                                                    5 non-null      object
#  1   Dirección de correo electrónico                                                                                   5 non-null      object
#  2   Código del Alumno                                                                                                 5 non-null      object
#  3   2. Porque me resulta placentero aprender cosas nuevas.                                                            5 non-null      float64
#  4   9. Por el placer que experimento descubriendo cosas nuevas que no he visto antes.                                 5 non-null      float64
#  5   16. Por lo placentero que me resulta ampliar mi conocimiento en temas atractivos para mi.                         5 non-null      float64
#  6   23. Porque me permetirá continuar aprendiendo sobre cosas que me interesan.                                       4 non-null      float64
#  7   6. Por el placer que siento al superarme a mi mismo en mis estudios.                                              5 non-null      float64
#  8   13. Porque me resulta placentero sobrepasarme a mi mismo obteniendo logros personales.                            4 non-null      float64
#  9   20. Por la satisfacción que siento en el proceso de superar actividades académicas complejas.                     5 non-null      float64
#  10  27. Porque me permite experimentar satisfacción personal la búsqueda por sobresalir en mis estudios.              5 non-null      float64
#  11  4. Porque me gusta estar en clase de la asignatura                                                                5 non-null      float64
#  12  11. Para mi la clase de Física y Química es divertida                                                             5 non-null      float64
#  13  18. Por el placer que experimento involucrandome en discusiones interesantes sobre la asignatura con el profesor  4 non-null      float64
#  14  25. Por la buena sensación que experimento leyendo sobre las cosas interesantes de la asignatura.                 5 non-null      float64
#  15  3. Porque pienso que me preparará mejor para el futuro profesional que he elegido.                                5 non-null      float64
#  16  10. Para que llegado el momento pueda acceder al mercado laboral en el campo que me gusta.                        5 non-null      float64
#  17  17. Porque me ayudará a tomar mejores decisiones respecto a mi futuro profesional.                                5 non-null      float64
#  18  24. Porque esta formación mejorará mis competencias como trabajador                                               5 non-null      float64
#  19  7. Para demostrarme a mis mismo que soy capaz de superar la  asignatura.                                          5 non-null      float64
#  20  14. Por el hecho de que me  siento importante teniendo éxito en la asignatura.                                    5 non-null      float64
#  21  21. Para demostrarme a mi mismo que soy una persona inteligente                                                   5 non-null      float64
#  22  28. Porque quiero demostrarme a mi mismo que puedo tener éxito en la asignatura.                                  5 non-null      float64
#  23  1. Porque necesito estos conocimientos para tener un trabajo bien pagado en el futuro                             5 non-null      float64
#  24  8. Para tener un trabajo mas prestigioso en el futuro.                                                            5 non-null      float64
#  25  15. Porque quiero tener "una buena vida" en el futuro.                                                            5 non-null      float64
#  26  22. Para tener un buen salario u otros beneficios en el futuro                                                    5 non-null      float64
#  27  5. Honestamente , no lo sé; realmente siento que estoy perdiendo el tiempo en esta asignatura.                    5 non-null      float64
#  28  12. En principio tenia buenos motivos para elegir esta asignatura, ahora me pregunto si debería seguir.           5 non-null      float64
#  29  19. Francamente no entiendo que hago en esta asignatura, no me podría importar menos.                             5 non-null      float64
#  30  26. No lo sé, no comprendo que hago en esta asignatura                                                            4 non-null      float64
# dtypes: float64(28), object(3)
# memory usage: 1.3+ KB

# %% [markdown]
# #Filtrado de Variables
# Se podria dar el caso de que no todas nuestras variables fuesen numericas y necesitasemos filtrarlas

# %%
df_num = test_df.select_dtypes(include = ['float','integer'])
#df_categorical = test_df.select_dtypes(include = ['O'])
df_num
# Out:
#    2. Porque me resulta placentero aprender cosas nuevas.  ...  26. No lo sé, no comprendo que hago en esta asignatura
# 0                                                3.0       ...                                                NaN
# 1                                                6.0       ...                                                3.0
# 2                                                2.0       ...                                                7.0
# 3                                                2.0       ...                                                7.0
# 4                                                2.0       ...                                                6.0
#
# [5 rows x 28 columns]

# %% [markdown]
# #Histogramas

# %%
df_num.hist(figsize=(15,20), bins=5, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe277206ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe277151a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2770ffc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2770b2ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe27706e198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe27709e400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe27704e668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276fff898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276fff908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276fdfda0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe276f93fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276f522b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276f04518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276eb9780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276e6e9e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe276e9fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276e56eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276e15160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276dcb3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276d7b630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe276d30898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276d65b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2770bfba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276f744e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe276e64c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe27aa08eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe28475fcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2865ab898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe28517aac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2847bacc0>]],
#       dtype=object)

# %% [markdown]
# #Correlación entre variables
# Mapa de calor, deberia aparecer correlación entre las preguntas que miden el mismo factor.

# %%
#df_num.corr()
plt.figure(figsize=(20,20))
sns.heatmap(df_num.corr(), square=True, annot=True, linewidths=.5)
plt.title("Correlation matrix among numerical variables")
plt.show()

# %% [markdown]
# Lista de las mas correlacionadas. Aqui deberiamos encontrar las preguntas que miden el mismo factor

# %%
df_numerical_corr = df_num.corr().iloc[:,[27]]
df_numerical_corr
# Out:
#                                                     26. No lo sé, no comprendo que hago en esta asignatura
# 2. Porque me resulta placentero aprender cosas ...                                          -0.968496
# 9. Por el placer que experimento descubriendo c...                                          -0.893413
# 16. Por lo placentero que me resulta ampliar mi...                                          -0.862662
# 23. Porque me permetirá continuar aprendiendo s...                                          -0.871602
# 6. Por el placer que siento al superarme a mi m...                                          -0.968496
# 13. Porque me resulta placentero sobrepasarme a...                                          -0.995871
# 20. Por la satisfacción que siento en el proces...                                          -0.965824
# 27. Porque me permite experimentar satisfacción...                                          -0.781661
# 4. Porque me gusta estar en clase de la asignatura                                          -0.675012
# 11. Para mi la clase de Física y Química es div...                                          -0.924658
# 18. Por el placer que experimento involucrandom...                                          -0.457496
# 25. Por la buena sensación que experimento leye...                                          -0.906977
# 3. Porque pienso que me preparará mejor para el...                                          -0.906977
# 10. Para que llegado el momento pueda acceder a...                                          -0.906977
# 17. Porque me ayudará a tomar mejores decisione...                                          -0.689701
# 24. Porque esta formación mejorará mis competen...                                          -0.613795
# 7. Para demostrarme a mis mismo que soy capaz d...                                          -0.968496
# 14. Por el hecho de que me  siento importante t...                                          -0.675012
# 21. Para demostrarme a mi mismo que soy una per...                                          -0.695978
# 28. Porque quiero demostrarme a mi mismo que pu...                                          -0.862662
# 1. Porque necesito estos conocimientos para ten...                                          -0.503028
# 8. Para tener un trabajo mas prestigioso en el ...                                          -0.289346
# 15. Porque quiero tener "una buena vida" en el ...                                          -0.025777
# 22. Para tener un buen salario u otros benefici...                                           0.283547
# 5. Honestamente , no lo sé; realmente siento qu...                                           0.978167
# 12. En principio tenia buenos motivos para eleg...                                           0.503220
# 19. Francamente no entiendo que hago en esta as...                                           0.853684
# 26. No lo sé, no comprendo que hago en esta asi...                                           1.000000

# %%
df_numerical_most_corr = df_numerical_corr[abs(df_numerical_corr) > 0.97].sort_values(by='26. No lo sé, no comprendo que hago en esta asignatura', ascending='false')
df_numerical_most_corr
# Out:
#                                                     26. No lo sé, no comprendo que hago en esta asignatura
# 13. Porque me resulta placentero sobrepasarme a...                                          -0.995871
# 5. Honestamente , no lo sé; realmente siento qu...                                           0.978167
# 26. No lo sé, no comprendo que hago en esta asi...                                           1.000000
# 2. Porque me resulta placentero aprender cosas ...                                                NaN
# 9. Por el placer que experimento descubriendo c...                                                NaN
# 16. Por lo placentero que me resulta ampliar mi...                                                NaN
# 23. Porque me permetirá continuar aprendiendo s...                                                NaN
# 6. Por el placer que siento al superarme a mi m...                                                NaN
# 20. Por la satisfacción que siento en el proces...                                                NaN
# 27. Porque me permite experimentar satisfacción...                                                NaN
# 4. Porque me gusta estar en clase de la asignatura                                                NaN
# 11. Para mi la clase de Física y Química es div...                                                NaN
# 18. Por el placer que experimento involucrandom...                                                NaN
# 25. Por la buena sensación que experimento leye...                                                NaN
# 3. Porque pienso que me preparará mejor para el...                                                NaN
# 10. Para que llegado el momento pueda acceder a...                                                NaN
# 17. Porque me ayudará a tomar mejores decisione...                                                NaN
# 24. Porque esta formación mejorará mis competen...                                                NaN
# 7. Para demostrarme a mis mismo que soy capaz d...                                                NaN
# 14. Por el hecho de que me  siento importante t...                                                NaN
# 21. Para demostrarme a mi mismo que soy una per...                                                NaN
# 28. Porque quiero demostrarme a mi mismo que pu...                                                NaN
# 1. Porque necesito estos conocimientos para ten...                                                NaN
# 8. Para tener un trabajo mas prestigioso en el ...                                                NaN
# 15. Porque quiero tener "una buena vida" en el ...                                                NaN
# 22. Para tener un buen salario u otros benefici...                                                NaN
# 12. En principio tenia buenos motivos para eleg...                                                NaN
# 19. Francamente no entiendo que hago en esta as...                                                NaN

# %% [markdown]
# Relacion entre las variables

# %%
for idx in df_numerical_most_corr.index[0:3]:
    test_df.plot(kind='scatter',
          x=idx,
          y='26. No lo sé, no comprendo que hago en esta asignatura')

# %% [markdown]
# #¿Que tipo de alumnos tenemos?
# Clasificaremos a los alumnos en clusteres en función de su tipo de motivación usando una libreria de machine learning que nos ayudara a encontrar a los subgrupos de alumnos que se encuentrar a una distancia euclidea menor entre ellos, dentro del espacio de 28 dimensiones que son cada una de las preguntas

# %%
from sklearn.cluster import KMeans

# %%
#dataset=df_num.to_xarray()
X = test_df.iloc[:,3:].values

# %%
X
# Out:
# array([[ 3.,  3.,  3., nan,  2.,  2.,  7.,  2.,  2.,  2., nan,  7.,  7.,
#          7.,  6.,  2.,  7.,  3.,  3.,  7.,  6.,  1.,  5.,  7.,  5.,  7.,
#          1., nan],
#        [ 6.,  6.,  5.,  5.,  5.,  5.,  5.,  4.,  4.,  6.,  3.,  5.,  6.,
#          5.,  4.,  5.,  5.,  4.,  5.,  4.,  6.,  5.,  5.,  3.,  2.,  2.,
#          1.,  3.],
#        [ 2.,  2.,  3.,  2.,  1., nan,  2.,  3.,  1.,  1.,  2.,  1.,  2.,
#          2.,  3.,  4.,  2.,  3.,  4.,  2.,  6.,  6.,  7.,  6.,  7.,  2.,
#          6.,  7.],
#        [ 2.,  2.,  1.,  3.,  1.,  2.,  1.,  2.,  3.,  2.,  3.,  2.,  3.,
#          1.,  2.,  3.,  2.,  1.,  1.,  3.,  1.,  2.,  3.,  2.,  6.,  7.,
#          5.,  7.],
#        [ 2.,  1.,  3.,  2.,  1.,  3.,  2.,  2.,  1.,  1.,  2.,  1.,  2.,
#          1.,  4.,  2.,  2.,  1.,  3.,  3.,  4.,  3.,  4.,  4.,  5.,  5.,
#          7.,  6.]])

# %% [markdown]
# Hay gente que se deja preguntas sin contestar y vamos a sustituir los faltantes por la media para no perturbar el analisis demasiado

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X)
(X)= imputer.transform(X)
X
# Out:
# array([[3.  , 3.  , 3.  , 3.  , 2.  , 2.  , 7.  , 2.  , 2.  , 2.  , 2.5 ,
#         7.  , 7.  , 7.  , 6.  , 2.  , 7.  , 3.  , 3.  , 7.  , 6.  , 1.  ,
#         5.  , 7.  , 5.  , 7.  , 1.  , 5.75],
#        [6.  , 6.  , 5.  , 5.  , 5.  , 5.  , 5.  , 4.  , 4.  , 6.  , 3.  ,
#         5.  , 6.  , 5.  , 4.  , 5.  , 5.  , 4.  , 5.  , 4.  , 6.  , 5.  ,
#         5.  , 3.  , 2.  , 2.  , 1.  , 3.  ],
#        [2.  , 2.  , 3.  , 2.  , 1.  , 3.  , 2.  , 3.  , 1.  , 1.  , 2.  ,
#         1.  , 2.  , 2.  , 3.  , 4.  , 2.  , 3.  , 4.  , 2.  , 6.  , 6.  ,
#         7.  , 6.  , 7.  , 2.  , 6.  , 7.  ],
#        [2.  , 2.  , 1.  , 3.  , 1.  , 2.  , 1.  , 2.  , 3.  , 2.  , 3.  ,
#         2.  , 3.  , 1.  , 2.  , 3.  , 2.  , 1.  , 1.  , 3.  , 1.  , 2.  ,
#         3.  , 2.  , 6.  , 7.  , 5.  , 7.  ],
#        [2.  , 1.  , 3.  , 2.  , 1.  , 3.  , 2.  , 2.  , 1.  , 1.  , 2.  ,
#         1.  , 2.  , 1.  , 4.  , 2.  , 2.  , 1.  , 3.  , 3.  , 4.  , 3.  ,
#         4.  , 4.  , 5.  , 5.  , 7.  , 6.  ]])

# %% [markdown]
# Veremos cuantos tipos de alumnos es razonable que encontremos

# %%
wcss = []
for i in range(1, 5):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 5), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# El codo de la curva nos indica que es razonable agrupar a los alumnos en ------- tipos y procederemos a aplicar el metodo.

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# ahora agrupamos la suma de todas las preguntas conrrespondientes a Motivacion Intrinseca y Extrinseca

# %%
X=np.c_[X,X[:,0:12].sum( axis=1),X[:,12:24].sum( axis=1)]
X.shape
# Out:
# (5, 30)

# %% [markdown]
# a continuación representaremos graficamente esos grupos de estudiantes

# %%
plt.scatter(X[y_kmeans == 0,28], X[y_kmeans == 0, 29], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 28], X[y_kmeans == 1, 29], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 28], X[y_kmeans == 2, 29], s = 100, c = 'green', label = 'Cluster 3')
#plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
#plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters de estudiantes')
plt.xlabel('Motivación Intrinseca')
plt.ylabel('Motivación Extrinseca')
plt.legend()
plt.show()

# %% [markdown]
# #Posibles Mejoras
# Devolver a los alumnos los resultados del analisis estadístico

# %%
# Import Python Packages
import smtplib# Set Global Variables
gmail_user = 'YOUR EMAIL'
gmail_password = 'YOUR PASSWORD'# Create Email 
mail_from = gmail_user
#abria que hacer un bucle con los destinatarios sacados de la columna de la hoja de calculo donde se almacena
mail_to = 'DESTINATOR EMAIL'
mail_subject = 'Hello'
mail_message_body = 'Hello World!'

mail_message = '''\
From: %s
To: %s
Subject: %s
# %s
''' % (mail_from, mail_to, mail_subject, mail_message_body)# Sent Email
server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
server.login(gmail_user, gmail_password)
server.sendmail(mail_from, mail_to, mail_message)
server.close()
